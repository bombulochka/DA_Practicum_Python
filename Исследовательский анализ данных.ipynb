# %% [markdown]
# <div  style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
#
# **Привет!**
#
# Меня зовут Василий Митров и я буду проверять твой проект. Предлагаю общаться на «ты». Если это неприемлемо, то дай мне знать и мы перейдем на «вы».
#
# Для удобства я оставлю комментарии в отдельных ячейках Markdown с заголовком «Комментарий ревьюера». Пожалуйста, не перемещай, не изменяй и не удаляй их - так наше общение будет более продуктивным. Я буду использовать цветовую разметку:
#
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера</b>
#
# ✍ Так выделены самые важные замечания. Без их отработки проект не будет принят. При проверке я обращаю внимание не только на код, но и на интерпретацию и анализ результатов, а также соответствие данных техническому заданию.
# </div>
#
# <div class="alert alert-warning" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера</b>
#
# 📝 Так выделены небольшие замечания или рекомендации. Постарайся, пожалуйста, учесть эти комментарии в этом проекте или в будущих проектах.
# </div>
#
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера</b>
#
# 👍 Так выделены все остальные комментарии, включая рекомендации, позитивные моменты или какие-то рассуждения и пояснения.
# </div>
#
# **Важные дополнения:**
#
# * <u>Идеально, когда проект структурирован. Где названия разделов и подразделов будут записаны в ячейках [Markdown](https://paulradzkov.com/2014/markdown_cheatsheet/?).</u>
#
#
# * <u>Проверь проект на работоспособность перед отправкой на проверку. Сделать это можно так: `Kernel -> Restart And Run All -> Restart And Run All Cells` предварительно сохранив проект нажав на дискету в левом верхнем углу. Это важный навык, который тебе пригодится как на собеседовании, при выполнении тестового задания, так и перед совещанием у руководства компании. Помни, ревьюеры не вносят изменения в код, даже если это путь к датасету или ячейка в неверном формате (code/mardown).</u>
#
# Давай работать над проектом в диалоге: если ты что-то меняешь в проекте или отвечаешь на мои комментарии — пиши об этом. Мне будет легче отследить изменения, если ты выделишь свои комментарии:
#
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# Например, вот так. Также, если есть какие-то вопросы, или что-то осталось непонятным по ревью - спрашивай в таких блоках и я постараюсь дать ответ.
# </div>
#
# ---

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекс Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет. Вам нужно научиться определять рыночную стоимость объектов недвижимости. Для этого проведите исследовательский анализ данных и установите параметры, влияющие на цену объектов. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые — получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта и других объектов — эти данные автоматически получены из геосервисов. Количество парков и водоёмов также заполняется без участия пользователя.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Правильно делаешь, что не убираешь описание задачи. Это поможет быстро вспомнить, о чем проект, если ты к нему вернешься спустя какое-то время.
#
# Данный блок можно расширить при помощи плана работы и описания данных. Посмотреть подробнее про вступительный блок можно в разделе "Полезные инструкции в учебе" блока "Оформление проекта".
#
#
# </div>

# %% [markdown]
# # Описание данных
# * airports_nearest — расстояние до ближайшего аэропорта в метрах (м)
# * balcony — число балконов
# * ceiling_height — высота потолков (м)
# * cityCenters_nearest — расстояние до центра города (м)
# * days_exposition — сколько дней было размещено объявление (от публикации до снятия)
# * first_day_exposition — дата публикации
# * floor — этаж
# * floors_total — всего этажей в доме
# * is_apartment — апартаменты (булев тип)
# * kitchen_area — площадь кухни в квадратных метрах (м²)
# * last_price — цена на момент снятия с публикации
# * living_area — жилая площадь в квадратных метрах (м²)
# * locality_name — название населённого пункта
# * open_plan — свободная планировка (булев тип)
# * parks_around3000 — число парков в радиусе 3 км
# * parks_nearest — расстояние до ближайшего парка (м)
# * ponds_around3000 — число водоёмов в радиусе 3 км
# * ponds_nearest — расстояние до ближайшего водоёма (м)
# * rooms — число комнат
# * studio — квартира-студия (булев тип)
# * total_area — общая площадь квартиры в квадратных метрах (м²)
# * total_images — число фотографий квартиры в объявлении

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Откройте-файл-с-данными-и-изучите-общую-информацию" data-toc-modified-id="Откройте-файл-с-данными-и-изучите-общую-информацию-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Откройте файл с данными и изучите общую информацию</a></span></li><li><span><a href="#Выполните-предобработку-данных" data-toc-modified-id="Выполните-предобработку-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Выполните предобработку данных</a></span></li><li><span><a href="#Добавьте-в-таблицу-новые-столбцы" data-toc-modified-id="Добавьте-в-таблицу-новые-столбцы-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Добавьте в таблицу новые столбцы</a></span></li><li><span><a href="#Проведите-исследовательский-анализ-данных" data-toc-modified-id="Проведите-исследовательский-анализ-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Проведите исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Изучим-перечисленные-ниже-параметры-объектов-и-построим-отдельные-гистограммы-для-каждого-из-этих-параметров." data-toc-modified-id="Изучим-перечисленные-ниже-параметры-объектов-и-построим-отдельные-гистограммы-для-каждого-из-этих-параметров.-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Изучим перечисленные ниже параметры объектов и построим отдельные гистограммы для каждого из этих параметров.</a></span></li><li><span><a href="#Изучим,-как-быстро-продавались-квартиры." data-toc-modified-id="Изучим,-как-быстро-продавались-квартиры.-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Изучим, как быстро продавались квартиры.</a></span></li><li><span><a href="#Определим-факторы,-которые-больше-всего-влияют-на-общую-(полную)-стоимость-объекта." data-toc-modified-id="Определим-факторы,-которые-больше-всего-влияют-на-общую-(полную)-стоимость-объекта.-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Определим факторы, которые больше всего влияют на общую (полную) стоимость объекта.</a></span></li><li><span><a href="#Посчитаем-среднюю-цену-одного-квадратного-метра-в-10-населённых-пунктах-с-наибольшим-числом-объявлений." data-toc-modified-id="Посчитаем-среднюю-цену-одного-квадратного-метра-в-10-населённых-пунктах-с-наибольшим-числом-объявлений.-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Посчитаем среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений.</a></span></li><li><span><a href="#Вычислим-среднюю-стоимость-квартир-в-Санкт-Петербурге-на-разном-удалении-от-центра." data-toc-modified-id="Вычислим-среднюю-стоимость-квартир-в-Санкт-Петербурге-на-разном-удалении-от-центра.-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Вычислим среднюю стоимость квартир в Санкт-Петербурге на разном удалении от центра.</a></span></li></ul></li><li><span><a href="#Напишите-общий-вывод" data-toc-modified-id="Напишите-общий-вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Напишите общий вывод</a></span></li></ul></div>

# %% [markdown]
# ### Откройте файл с данными и изучите общую информацию

# %%
import pandas as pd
import matplotlib.pyplot as plot

# %%
data = pd.read_csv('/datasets/real_estate_data.csv', sep='\t')
data.head(20)
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 0             20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1              7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2             10   5196000.0       56.00  2015-08-20T00:00:00      2
# 3              0  64900000.0      159.00  2015-07-24T00:00:00      3
# 4              2  10000000.0      100.00  2018-06-19T00:00:00      2
# 5             10   2890000.0       30.40  2018-09-10T00:00:00      1
# 6              6   3700000.0       37.30  2017-11-02T00:00:00      1
# 7              5   7915000.0       71.60  2019-04-18T00:00:00      2
# 8             20   2900000.0       33.16  2018-05-23T00:00:00      1
# 9             18   5400000.0       61.00  2017-02-26T00:00:00      3
# 10             5   5050000.0       39.60  2017-11-16T00:00:00      1
# 11             9   3300000.0       44.00  2018-08-27T00:00:00      2
# 12            10   3890000.0       54.00  2016-06-30T00:00:00      2
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# В исходных данных много пропущенных значений, присутствуют некорректные типы данных, не все названия столбцов приведены к нижнему регистру.

# %%
data.columns = data.columns.str.lower()

# %%
data.hist(figsize=(15, 20));

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Предупреждения перед графиками можно убрать одним из способов:
#
# 1. В конец кода добавить `plt.show()`, но для этого нужно вызвать библиотеку matplotlib.pyplot as plt
# 2. В конец кода добавить `;`
# </div>

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 📝 Здесь у нас заканчивается вводная часть ознакомления с данными. Основная информация получена. Было бы неплохо также привести небольшое заключение по объему данных и основных ошибках, которые уже были обнаружены на этой стадии (типы данных, пропуски и др).
# </div>

# %% [markdown]
# ### Выполните предобработку данных

# %% [markdown]
# Посмотрим количество пропусков в данных.

# %%
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# citycenters_nearest      5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 📝
# Также, помимо абсолютных значений мы можем посмотреть долю пропусков, и на основании этого принять решение о удалении, замене либо игнорировании пропусков, например: `pd.DataFrame(round(df.isna().mean()*100,1)).style.background_gradient('coolwarm')`
#
#
# </div>

# %% [markdown]
# Пропуски присутствуют в полях:
# * ceiling_height           9195
# * floors_total               86
# * living_area              1903
# * is_apartment            20924
# * kitchen_area             2278
# * balcony                 11519
# * locality_name              49
# * airports_nearest         5542
# * cityCenters_nearest      5519
# * parks_around3000         5518
# * parks_nearest           15620
# * ponds_around3000         5518
# * ponds_nearest           14589
# * days_exposition          3181
#
# Предположим, что причина пропусков в полях:
# * is_apartment            20924 - не является апартаментами
# * balcony                 11519 - отсутствие балконов
#
# Пользователи не заполнили эти данные из-за их отсутствия.
#
# Сделаем соответствующие замены.

# %%
data['is_apartment'] = data['is_apartment'].fillna(False)
data['balcony'] = data['balcony'].fillna(0)

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Все верно
# </div>

# %% [markdown]
# Пропуски могли возникнуть из-за того, что пользователи не предоставили данные либо эта информация не требовалась. Также могли возникнуть технические ошибки при автоматической выгрузке данных.

# %% [markdown]
# Изучим типы данных.

# %%
data.dtypes
# Out:
# total_images              int64
# last_price              float64
# total_area              float64
# first_day_exposition     object
# rooms                     int64
# ceiling_height          float64
# floors_total            float64
# living_area             float64
# floor                     int64
# is_apartment               bool
# studio                     bool
# open_plan                  bool
# kitchen_area            float64
# balcony                 float64
# locality_name            object
# airports_nearest        float64
# citycenters_nearest     float64
# parks_around3000        float64
# parks_nearest           float64
# ponds_around3000        float64
# ponds_nearest           float64
# days_exposition         float64
# dtype: object

# %%
data['first_day_exposition'] = pd.to_datetime(data['first_day_exposition'], format='%Y-%m-%dT%H:%M:%S')
data['balcony'] = data['balcony'].astype(int)

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍 При чтении файла можно указать параметр `parse_dates: parse_dates=['date']`. Тогда пандас автоматически переведет список столбцов в даты. Пример можно посмотреть [здесь](https://newtechaudit.ru/gruzi-daty-krasivo/).
# </div>

# %% [markdown]
# В поле 'first_day_exposition' указана дата, которой должен соответствовать тип datetime.
# В поле 'balcony' присутствуют только целые значения, поэтому логично присвоить данным тип int.

# %% [markdown]
# Устраним неявные дубликаты.

# %%
data['locality_name'].unique()
# Out:
# array(['Санкт-Петербург', 'посёлок Шушары', 'городской посёлок Янино-1',
#        'посёлок Парголово', 'посёлок Мурино', 'Ломоносов', 'Сертолово',
#        'Петергоф', 'Пушкин', 'деревня Кудрово', 'Коммунар', 'Колпино',
#        'поселок городского типа Красный Бор', 'Гатчина', 'поселок Мурино',
#        'деревня Фёдоровское', 'Выборг', 'Кронштадт', 'Кировск',
#        'деревня Новое Девяткино', 'посёлок Металлострой',
#        'посёлок городского типа Лебяжье',
#        'посёлок городского типа Сиверский', 'поселок Молодцово',
#        'поселок городского типа Кузьмоловский',
#        'садовое товарищество Новая Ропша', 'Павловск',
#        'деревня Пикколово', 'Всеволожск', 'Волхов', 'Кингисепп',
#        'Приозерск', 'Сестрорецк', 'деревня Куттузи', 'посёлок Аннино',
#        'поселок городского типа Ефимовский', 'посёлок Плодовое',
#        'деревня Заклинье', 'поселок Торковичи', 'поселок Первомайское',
# ...

# %%
data['locality_name'] = (data['locality_name']
                        .str.replace('ё', 'е')
                        .replace(['поселок городского типа', 'городской поселок'], 'поселок', regex=True))

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Отлично! Можно еще применить такой подход:
#
#     df = df.apply(lambda x: x.replace({'поселок':'посёлок', 'городской посёлок': 'посёлок', 'посёлок городского типа': 'посёлок', 'коттеджный посёлок': 'посёлок', 'посёлок при железнодорожной станции': 'посёлок станции'}, regex=True))
#
#     len(df.locality_name.unique())
# </div>

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Молодец, что не забываешь про явные дубликаты.
# </div>

# %% [markdown]
# Строки-дубликаты в данных отсутствуют.

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# ✍
# Замечания поподразделу:
#
# * Рассмотрены и объяснены не все столбцы с пропусками. Так, например, Высоту можно заполнить медианой с учетом группировки по локации или расстоянию до центра в км, логично что в большинстве случаев потолки в исторической застройке выше. Либо же как вариант заполнить медианой.
#
#
# * Обрати, пожалуйста, внимание на тип данных в столбце floors_total, вряд ли он должен быть дробным.
#
#
# * Отсутствует промежуточный вывод о проделанной работе в разделе.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# Заполним пропуски в данных по высоте потолков и количеству этажей в домах.
# Для этого категоризируем данные по удаленности от центра.
# </div>

# %%
data['citycenters_nearest_km'] = (data['citycenters_nearest']/1000).round(0)
#Категоризируем данные по удаленности от центра
data.loc[data['citycenters_nearest_km'] <= 20, 'citycenters_type'] = 'near'
data.loc[(data['citycenters_nearest_km'] > 20)&(data['citycenters_nearest_km'] <= 40), 'citycenters_type'] = 'medium'
data.loc[data['citycenters_nearest_km'] > 40, 'citycenters_type'] = 'far'
#Заполним высоту потолка и этажность домов медианным значением с учетом удаленности от центра
for i in data['citycenters_type'].unique():
        data.loc[data['citycenters_type']==i, 'ceiling_height'] = \
        data.loc[data['citycenters_type']==i, 'ceiling_height'].fillna(data.loc[data['citycenters_type']==i, 'ceiling_height'].median())
        data.loc[data['citycenters_type']==i, 'floors_total'] = \
        data.loc[data['citycenters_type']==i, 'floors_total'].fillna(data.loc[data['citycenters_type']==i, 'floors_total'].median())

# %%
data['ceiling_height'].isna().sum()
# Out:
# 2575

# %%
# data['floors_total'] = data['floors_total'].astype(int)
data['floors_total'].isna().sum()
# Out:
# 10

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# Оставшиеся пропуски заполним медианным значением.
# </div>

# %%
data['ceiling_height'] = \
data['ceiling_height'].fillna(data['ceiling_height'].median())
data['floors_total'] = \
data['floors_total'].fillna(data['floors_total'].median())

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# Приведем колонку floors_total к целочисленному типу, так как количество этажей не может быть дробным.
# </div>

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 📝
# Что касается floors_total, то заполнять пропуски можно только в случае MCAR без искажения статистических свойств данных. Если пропуски MAR или MNAR, выбор метода заполнения должен основываться на глубоком понимании природы данных и причин пропусков.
#
# Таким образом, перед заполнением пропусков, важно определить, к какому типу они относятся и основывать свои действия на этом понимании. Если мы не уверены в характере пропусков, лучше оставить их незаполненными или использовать методы моделирования, устойчивые к пропускам данных. Обработка пропусков медианой в данном случае невозможна.
#
# **Типы пропущенных данных:**
#
# * MCAR (Missing Completely At Random): данные пропущены полностью случайно. В этом случае заполнение пропусков, скажем, медианным значением, не будет искажать распределение.
#
# * MAR (Missing At Random): пропуск в переменной зависит от других наблюдаемых переменных, но не зависит от самой пропущенной переменной.
#
# * MNAR (Missing Not At Random): пропуск в переменной зависит от самой пропущенной переменной.
#
# Доля пропусков здесь менее 5% и мы вполне можем их удалить.
# </div>

# %%
data['floors_total'] = data['floors_total'].astype(int)

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# При изучении данных были обнаружены пропуски, некорректные типы данных и неявные дубликаты.
# Там, где это возможно, сделаны логичные замены в пропущенных данных, высота потолков и количество этажей заполнены медианными значениями.
# Типы данных заменены на целочисленные в полях, где не может присутствовать дробных значений.
# Устранены неявные дубликаты в названиях населенных пунктов. Явных дубликатов не обнаружено.
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
#
# </div>

# %% [markdown]
# ### Добавьте в таблицу новые столбцы

# %%
data['meter_price'] = (data['last_price']/data['total_area']).round(2)

# %%
data['citycenters_nearest_km'] = (data['citycenters_nearest']/1000).round(0)

# %%
data['weekday'] = data['first_day_exposition'].astype('datetime64[W]')
data['month'] = data['first_day_exposition'].astype('datetime64[M]')
data['year'] = data['first_day_exposition'].astype('datetime64[Y]')

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 📝
# Совет на будущие работы: обычно в датафреймах содержатся данные за несколько лет. Важно выбрать корректный метод для вычленения месяца, иначе месяца разных годов могут стать одним месяцем. Обрати внимание на метод astype('datetime64[M]'). Для его использования не нужно обращаться к pd.DatetimeIndex.
#
# Вот хорошая статья на этот счёт:
#
#     https://pythobyte.com/how-to-work-with-dates-and-times-in-python-0a176355/
#
#     и
#
#     https://stackoverflow.com/questions/70901855/get-hour-and-minutes-and-seconds-from-numpy-datetime64
#
# Этот метод нужен для визуализации динамики по неделям, месяцам или годам (смотря какой метод выберешь)
#
# Код выглядит так:
#
#         df['first_day_exposition'].dt.date #приводим к временному формату
#         df['first_day_exposition'].astype('datetime64[M]')
#
# Если года разные, то в новой колонке месяца у тебя отобразится первый день месяца ('2019-05-01')
# </div>

# %%
data.loc[data['floor'] == data['floors_total'], 'floor_type'] = 'Последний' 
data.loc[data['floor'] == 1, 'floor_type'] = 'Первый'
data['floor_type'] = data['floor_type'].fillna('Другой')

# %%
data.head(5)
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0           2019-03-07      3
# 1             7   3350000.0        40.4           2018-12-04      1
# 2            10   5196000.0        56.0           2015-08-20      2
# 3             0  64900000.0       159.0           2015-07-24      3
# 4             2  10000000.0       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0            2.70            16         51.0      8         False  ...
# 1            2.70            11         18.6      1         False  ...
# 2            2.70             5         34.3      4         False  ...
# 3            2.70            14          NaN      9         False  ...
# 4            3.03            14         32.0     13         False  ...
#
#    ponds_around3000  ponds_nearest  days_exposition  citycenters_nearest_km  \
# ...

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍 Отлично! Можем приступать к исследовательскому анализу.
# </div>

# %% [markdown]
# ### Проведите исследовательский анализ данных

# %% [markdown]
# #### Изучим перечисленные ниже параметры объектов и построим отдельные гистограммы для каждого из этих параметров.
# * общая площадь; total_area
# * жилая площадь; living_area
# * площадь кухни; kitchen_area
# * цена объекта; last_price
# * количество комнат; rooms
# * высота потолков; ceiling_height
# * тип этажа квартиры («первый», «последний», «другой»); floor_type
# * общее количество этажей в доме; floors_total
# * расстояние до центра города в метрах; cityCenters_nearest
# * расстояние до ближайшего парка parks_nearest

# %%
data.hist('total_area', bins=30)
plot.title('Общая площадь')
plot.xlabel("кв.м.");

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# ✍
# Обрати, пожалуйста, внимание на оформление графиков в проекте. Важно, чтобы у каждого графика было название, а оси были четко подписаны. Пожалуйста, пройдись по всем графикам и убедись в их корректном оформлении.
#
# Помни, график — это инструмент общения с заказчиком. Он должен быть ясным, лаконичным и информативным.
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
#
# </div>

# %%
(data['total_area'][data['total_area'] > 200].count()/data['total_area'].count()*100).round(2)
# Out:
# 0.96

# %% [markdown]
# Большая часть квартир имеет общую площадь до 200 квадратных метров. Общую площадь более 200 квадратных метров имеет менее 1 процента квартир. Отбросим нетипично большие квартиры.

# %%
data = data.query('total_area <= 200')
data.hist('total_area', bins=30)
plot.title('Общая площадь')
plot.xlabel("кв.м.");

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍 Верно, с большей площадью меньше предложений. Объекты выше 90-100 кв. м - это более дорогой сегмент.
# </div>

# %%
data.hist('living_area', bins=30)
plot.title('Жилая площадь')
plot.xlabel("кв.м.");

# %%
(data['living_area'][data['living_area'] > 100].count()/data['living_area'].count()*100).round(2)
# Out:
# 0.8

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# Большая часть квартир имеет жилую площадь до 100 квадратных метров. Жилую площадь более 100 квадратных метров имеет менее 1 процента квартир.
# Квартиры с нетипично большой жилой площадью исключим.
# </div>

# %%
data = data.query('living_area <= 100')
data.hist('living_area', bins=30)
plot.title('Жилая площадь')
plot.xlabel("кв.м.");

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# ✍
# Вывод по параметру
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
#
# </div>

# %%
data.hist('kitchen_area', bins=30)
plot.title('Площадь кухни')
plot.xlabel("кв.м.");

# %%
(data['kitchen_area'][data['kitchen_area'] > 40].count()/data['total_area'].count()*100).round(2)
# Out:
# 0.38

# %% [markdown]
# Большая часть кухонь в продаваемых квартирах имеет площадь до 40 квадратных метров. Размер более 40 квадратных метров имеет менее 1 процента кухонь. Отбросим квартиры с нетипично большими кухнями.

# %%
data = data.query('kitchen_area <= 40')
data.hist('kitchen_area', bins=30)
plot.title('Площадь кухни')
plot.xlabel("кв.м.");

# %%
data.hist('last_price',bins = 30)
plot.title('Цена объекта')
plot.xlabel("р.");

# %%
(data['last_price'][data['last_price'] > 30*10**6].count()/data['last_price'].count()*100).round(2)
# Out:
# 0.55

# %% [markdown]
# Стоимость большинства квартир не превышает 30 млн. Менее 1 процента квартир стоят более 30 млн. Отбросим нетипично дорогие квартиры.

# %%
data = data.query('last_price <= 30*10**6')

# %%
data.hist('last_price',bins = 30)
plot.title('Цена объекта')
plot.xlabel("р.");

# %%
data.hist('rooms', bins=20)
plot.title('Количество комнат')
plot.xlabel("шт.");

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# Почти все квартиры имеют 1-3 комнаты. Редкие квартиры имеют более трех комнат.
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# ✍
# Вывод
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍Верно, однокомнатные популярней по ряду причин: цена(доступней для одиноких людей, а также людям в гражданском браке), рентабельность(покупка с целью продать дороже, а так же сдача в наём для приезжих, студентов и т.д), наследство.
# </div>

# %%
data.hist('ceiling_height')
plot.title('Высота потолков')
plot.xlabel("м.");

# %% [markdown]
# Значения высоты потолков более 10 метров можно считать аномальными, разделим эти значения на 10.

# %%
data.loc[data['ceiling_height'] >= 10, 'ceiling_height'] = data['ceiling_height']/10

# %%
data.hist('ceiling_height',bins=20)
plot.title('Высота потолков')
plot.xlabel("м.");

# %%
(data['ceiling_height'][(data['ceiling_height'] < 2)|(data['ceiling_height'] > 4)].count()/data['ceiling_height'].count()*100).round(2)
# Out:
# 0.16

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# Высота потолков большинства квартир находится в пределах 2-4 метров. Квартиры с потолками выше 4 метров и ниже 2 метров составляют только 0.16 процента квартир, исключим их как нетипичные.
# </div>

# %%
data = data.query('ceiling_height >= 2' and 'ceiling_height <= 4')

# %%
data.hist('ceiling_height')
plot.title('Высота потолков')
plot.xlabel("м.");

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# ✍
# Вывод
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
#
# </div>

# %%
data.groupby('floor_type')['floor'].count().plot(kind='pie', autopct='%1.0f%%', legend=True, title='Этаж');

# %% [markdown]
# Большая часть квартир, 74 процента, расположена не на первом или последнем этаже. На первом и на последнем этаже продается примерно равная доля квартир.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍 Да, чаще всего продают не последний и не первый этажи - такие этажи могут быть проблемными (заглядывают прохожие, холодно, жарко, протекает крыша и т.д.)
#
# Также это связано с этажностью строительства. Первый и последний этажи - это лишь по одному этажу, а группа "другой" включает в себя все этажи, кроме первого и последнего. Для 3-этажных домов мы бы увидели равномерное распределение, но строительство заметно выше, чем 3 этажа.
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# ✍
# Также прошу обратить внимание на оформление графика, если мы показываем соотношение на круговой диаграмме, то и сами доли необходимо отобразить на ней.
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
#
# </div>

# %%
data.hist('floors_total')
plot.title('Количество этажей')
plot.xlabel("шт.");

# %%
(data['floors_total'][data['floors_total'] > 30].count()/data['floors_total'].count()*100).round(2)
# Out:
# 0.14

# %% [markdown]
# Квартиры в малоэтажных домах продаются чаще. Только 0.14 пройента квартир в домах выше 30 этажей, отбросим квартиры в нетипично высоких домах.

# %%
data = data.query('floors_total <= 30')

# %%
data.hist('floors_total')
plot.title('Количество этажей')
plot.xlabel("шт.");

# %%
data.hist('citycenters_nearest')
plot.title('Расстояние до центра')
plot.xlabel("м.");

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# Большая часть продаваемых квартир расположены не далее 20 км от центра. Вероятно владельцы квартир, расположенных дальше, не указывали этот параметр.
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# ✍
# Вывод
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
#
# </div>

# %%
data.hist('parks_nearest')
plot.title('Расстояние до ближайшего парка')
plot.xlabel("м.");

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# Большая часть продаваемых квартир расположены не далее 1 км от ближайшего парка. Вероятно владельцы квартир, не имеющих поблизости парка, не указывали этот параметр.
# </div>

# %% [markdown]
# Судя по графикам среди продаваемых квартир преобладают квартиры небольшой площади, в  малоэтажных домах, рядом с центром.

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# ✍
# Прошу написать выводы и наблюдения исходя из графиков под каждым параметром.
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
#
# </div>

# %% [markdown]
# #### Изучим, как быстро продавались квартиры.

# %%
data.hist('days_exposition', bins=30)
plot.title('Период размещения объявления')
plot.xlabel("дней");

# %%
data['days_exposition'].mean()
# Out:
# 182.7899331141594

# %%
data['days_exposition'].median()
# Out:
# 100.0

# %% [markdown]
# Судя по медиане обычно продажа квартиры занимает 94 дня. Быстрыми можно считать продажи, которые заняли менее 94 дней. Среднее значение смещено вправо в сторону хвоста из-за наличия нетипично долгих продаж. Необычно долгими можно считать продажи, которые заняли более 800 дней.

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# ✍
# Немного не так, чтобы ответить на вопрос "Какие продажи можно считать быстрыми, а какие — необычно долгими?" лучше посмотреть на распределение данные с помощью boxplot() или describe(). Ориентироваться лучше на Q1.
# </div>

# %%
data.boxplot('days_exposition')
plot.title('Период размещения объявления')
plot.ylabel("дней");

# %%
data['days_exposition'].describe()
# Out:
# count    17642.000000
# mean       182.789933
# std        218.931658
# min          1.000000
# 25%         44.000000
# 50%        100.000000
# 75%        235.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# Быстрыми можно считать продажи, которые заняли менее 44 дней. Долгими можно считать продажи, занявшие более 235 дней.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
# Верно
# </div>

# %% [markdown]
# #### Определим факторы, которые больше всего влияют на общую (полную) стоимость объекта.
# Изучим, зависит ли цена от:
# * общей площади;
# * жилой площади;
# * площади кухни;
# * количества комнат;
# * этажа, на котором расположена квартира (первый, последний, другой);
# * даты размещения (день недели, месяц, год).

# %%
#напишем функцию для построения диаграмм рассеяния
def diagram(param, name):
    return data.plot(x='last_price', y=param, kind='scatter', alpha=0.03, grid=True, xlabel='Цена объекта', ylabel=name)

# %%
data[['last_price', 'total_area', 'living_area', 'kitchen_area', 'rooms']].corr()
# Out:
#               last_price  total_area  living_area  kitchen_area     rooms
# last_price      1.000000    0.769709     0.645917      0.589084  0.471043
# total_area      0.769709    1.000000     0.918838      0.544637  0.786533
# living_area     0.645917    0.918838     1.000000      0.289607  0.884250
# kitchen_area    0.589084    0.544637     0.289607      1.000000  0.158290
# rooms           0.471043    0.786533     0.884250      0.158290  1.000000

# %% [markdown]
# Коэффициент корреляции показывает, что существует прямая зависимость между стоимостью квартиры и ее общей площадью. Цена практически не зависит от даты размещения объявления.

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# ✍
# На рассмотренных выше параметров коэффициент корреляции Пирсона работал хорошо. Но применение его к остальным параметрам - типу этажа, дню недели, году, и месяцу - не эффективно, т.к. цена квартиры зависит от них не линейно.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# Убрала из расчета тип этажа, день недели, год и месяц.
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
#
# </div>

# %%
diagram('total_area', 'Общая площадь');

# %% [markdown]
# Цена на квартиру растет с увеличением общей площади квартиры.

# %%
diagram('living_area', 'Жилая площадь');

# %% [markdown]
# Цена на квартиру растет с увеличением жилой площади квартиры.

# %%
diagram('kitchen_area', 'Площадь кухни');

# %% [markdown]
# От площади кухни зависимость цены на квартиру не столь выражена.

# %%
diagram('rooms', 'Количество комнат');

# %% [markdown]
# Зависимости цены на квартиру от количества комнат не наблюдается. Квартиры с 3 комнатами продаются чаще и дороже других.

# %%
#Напишем функцию для сводных таблиц
def pivot(x):
    return (data.pivot_table(index=x, values='last_price', aggfunc='median').sort_values(by='last_price')
                   .reset_index().rename(columns={'last_price':'median_price'}))

# %%
pivot('floor_type')
# Out:
#   floor_type  median_price
# 0     Первый     3900000.0
# 1  Последний     4250000.0
# 2     Другой     4800000.0

# %% [markdown]
# Самые дешевые квартиры расположены на первом этаже. Медианная цена выше на квартиры, расположенные не на первом или последнем этажах.

# %%
diagram('floor_type', 'Тип этажа');

# %%
pivot('weekday')
# Out:
#        weekday  median_price
# 0   2016-07-21     3325000.0
# 1   2016-01-07     3600000.0
# 2   2016-08-25     3700000.0
# 3   2015-06-25     3724500.0
# 4   2015-04-16     3770000.0
# ..         ...           ...
# 226 2015-07-16     6900000.0
# 227 2016-10-27     7350000.0
# 228 2015-08-20     8625000.0
# 229 2015-09-03     9100000.0
# 230 2014-11-27    12298560.0
#
# [231 rows x 2 columns]

# %%
diagram('weekday', 'День недели');

# %%
data.groupby('weekday')['last_price'].median().plot(x='year', y='last_price', style='o-', grid=True)
plot.xlabel('День недели')
plot.ylabel('Цена объекта');

# %% [markdown]
# Выраженной зависимости цены на квартиру от дня недели размещения объявления не наблюдается. Самые высокие цены на квартиры во вторник, в течение недели цена падает и достигает минимума в субботу.

# %%
pivot('month')
# Out:
#         month  median_price
# 0  2016-08-01     4050000.0
# 1  2017-06-01     4200000.0
# 2  2016-07-01     4210000.0
# 3  2018-03-01     4295000.0
# 4  2017-10-01     4297500.0
# 5  2016-05-01     4300000.0
# 6  2017-07-01     4350000.0
# 7  2018-06-01     4400000.0
# 8  2016-03-01     4400000.0
# 9  2018-02-01     4450000.0
# 10 2017-03-01     4450000.0
# 11 2016-11-01     4450000.0
# 12 2017-08-01     4472000.0
# 13 2016-04-01     4490000.0
# 14 2016-06-01     4495000.0
# 15 2018-01-01     4499999.0
# 16 2016-02-01     4500000.0
# 17 2017-11-01     4500000.0
# 18 2017-05-01     4500000.0
# 19 2017-02-01     4500000.0
# 20 2017-04-01     4550000.0
# 21 2017-12-01     4589000.0
# 22 2018-04-01     4590000.0
# 23 2017-01-01     4590000.0
# 24 2015-06-01     4599500.0
# 25 2017-09-01     4600000.0
# 26 2016-12-01     4600000.0
# 27 2018-09-01     4650000.0
# 28 2018-10-01     4690000.0
# 29 2018-07-01     4690000.0
# 30 2015-12-01     4700000.0
# 31 2018-11-01     4777500.0
# ...

# %%
diagram('month', 'Месяц');

# %%
data.groupby('month')['last_price'].median().plot(x='year', y='last_price', style='o-', grid=True)
plot.xlabel('Месяц')
plot.ylabel('Цена объекта');

# %% [markdown]
# Выраженной зависимости цены на квартиру от месяца размещения объявления не наблюдается. Самые низкие цены в июне, самые высокие - в апреле и в декабре.

# %%
pivot('year')
# Out:
#         year  median_price
# 0 2016-01-01     4450000.0
# 1 2017-01-01     4500000.0
# 2 2018-01-01     4600000.0
# 3 2019-01-01     5000000.0
# 4 2015-01-01     5100000.0
# 5 2014-01-01     7100000.0

# %%
diagram('year', 'Год');

# %%
data.groupby('year')['last_price'].median().plot(x='year', y='last_price', style='o-', grid=True);
plot.xlabel('Год');
plot.ylabel('Цена объекта');

# %% [markdown]
# Цены на квартиры резко упали в 2014 году и только в 2016 году начали постепенно расти.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Верная интерпретация полученных данных.
# </div>

# %% [markdown]
# #### Посчитаем среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений.

# %%
(data.pivot_table(index='locality_name', values='meter_price', aggfunc=['median', 'count']).round(2).
sort_values(by=('count', 'meter_price'), ascending=False).head(10))
# Out:
#                        median       count
#                   meter_price meter_price
# locality_name
# Санкт-Петербург     103571.43       13493
# поселок Мурино       84876.54         429
# поселок Шушары       77312.83         392
# Всеволожск           65789.47         356
# Пушкин               99865.72         326
# Колпино              74722.22         321
# Гатчина              67796.61         289
# поселок Парголово    92271.98         288
# деревня Кудрово      91715.12         226
# Петергоф             81901.42         190

# %% [markdown]
# Среди населенных пунктов с самым большим количеством объявлений самая высокая цена за квадратный метр, более 100 тыс. рублей, в городах Санкт-Петербург и Пушкин. Самая низкая цена за квадратный метр в городе Выборг.

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 📝
# Таблица верна. Совет: на общие продажи лучше смотреть через призму медианы. Она более устойчива к выбросам.
#
# Также хорошо бы визуализировать получаемую информацию.
#
# </div>

# %% [markdown]
# #### Вычислим среднюю стоимость квартир в Санкт-Петербурге на разном удалении от центра.

# %%
data_grouped = (data.query('locality_name == "Санкт-Петербург"')
                .pivot_table(index='citycenters_nearest_km', values='last_price', aggfunc='mean').reset_index())
data_grouped.columns = ['citycenters_nearest_km', 'mean_price']
data_grouped
# Out:
#     citycenters_nearest_km    mean_price
# 0                      0.0  8.886667e+06
# 1                      1.0  1.135901e+07
# 2                      2.0  1.048462e+07
# 3                      3.0  9.065654e+06
# 4                      4.0  9.637472e+06
# 5                      5.0  1.020942e+07
# 6                      6.0  9.022081e+06
# 7                      7.0  8.961397e+06
# 8                      8.0  8.741738e+06
# 9                      9.0  6.714267e+06
# 10                    10.0  6.157184e+06
# 11                    11.0  6.013430e+06
# 12                    12.0  5.814130e+06
# 13                    13.0  6.019190e+06
# 14                    14.0  5.541995e+06
# 15                    15.0  5.690124e+06
# 16                    16.0  5.287759e+06
# 17                    17.0  5.252181e+06
# 18                    18.0  4.903730e+06
# 19                    19.0  5.112214e+06
# 20                    20.0  4.611579e+06
# 21                    21.0  5.168072e+06
# ...

# %%
data_grouped.plot(x='citycenters_nearest_km', y='mean_price', style='o-', grid=True);
plot.xlabel('Расстояние до центра, км');
plot.ylabel('Цена объекта');

# %% [markdown]
# Очевидно, с ростом удаленности квартиры от центра города стоимость квартиры падает.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍  Верно, дальше от центра - дешевле квартиры.
# </div>

# %% [markdown]
# ### Напишите общий вывод

# %% [markdown]
# Мы изучили полученные данные - архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет. Заполнили пропуски в данных там, где это было возможно, изменили некорректные типы данных, устранили неявные дубликаты, категоризировали данные по временным промежуткам, типу этажа, расстоянию до центра в километрах.
#
# Изучили следующие параметры объектов:
#
# * общая площадь;
# * жилая площадь;
# * площадь кухни;
# * цена объекта;
# * количество комнат;
# * высота потолков;
# * тип этажа квартиры («первый», «последний», «другой»);
# * общее количество этажей в доме;
# * расстояние до центра города в метрах;
# * расстояние до ближайшего парка.
#
# Устранили аномально высокие значения.
# Среди продаваемых квартир преобладают квартиры небольшой площади, в  малоэтажных домах, рядом с центром.
#
# Изучили скорость продажи квартир. Обычно продажа квартиры занимает 100 дней. Быстрыми можно считать продажи, которые заняли менее 44 дней. Долгими можно считать продажи, занявшие более 235 дней.
#
# Изучили, зависит ли цена от:
#
# * общей площади;
# * жилой площади;
# * площади кухни;
# * количества комнат;
# * этажа, на котором расположена квартира (первый, последний, другой);
# * даты размещения (день недели, месяц, год).
#
# Наибольшее влияние на цену квартиры оказывает общая площадь.
# Трехкомнатные квартиры продаются чаще и дороже других.
# Самые дешевые квартиры расположены на первом этаже.
# Самые высокие цены на квартиры во вторник, в течение недели цена падает и достигает минимума в субботу.
# Самые низкие цены в июне, самые высокие - в апреле и в декабре.
# Цены на квартиры резко упали в 2014 году и только в 2016 году начали постепенно расти.
#
# Среди населенных пунктов с самым большим количеством объявлений самая высокая цена за квадратный метр, более 100 тыс. рублей, была выявлена в городах Санкт-Петербург и Пушкин. Самая низкая цена за квадратный метр - в городе Выборг.
#
# По результатам изучения средней стоимости квартир в Санкт-Петербурге на разном удалении от центра можно сказать, что с ростом удаленности квартиры от центра города стоимость квартиры падает.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Выводы понятны и логичны, а самое главное подкреплены выявленными фактами.
#
# Ты очень серьезно подходишь к визуализации.
#
# Вот пара ссылок на полезные источники:
#
# * [Как строить красивые графики на Python с Seaborn](https://habr.com/ru/companies/otus/articles/540526/)
#
# * [Seaborn для визуализации данных в Python](https://pythonru.com/biblioteki/seaborn-plot)
# </div>

# %% [markdown]
# <div style="border:solid indigo 3px; padding: 20px">
# <div class="alert alert-success">
# <b>Обратная связь v.1</b>
#
# 👋
# Замечательная работа, ты мыслишь нестандартно, это отличный навык, который у тебя уже есть, видны последовательность и вдумчивость. Твою работу очень интересно читать и проверять.  Я оставил несколько обязательных поправок для тебя и после этого буду готов сразу принять проект.
#
# Удачи в доработках, жду!

# %% [markdown]
# <div style="border:solid indigo 3px; padding: 20px">
# <div class="alert alert-success">
# <b>Обратная связь v.2</b>
#
# 👋
#
# Спасибо тебе за исправления критических моментов, а также спасибо за хорошую работу.
#
# Поздравляю с успешным завершением проекта 🥳 🎉
#
# И желаю успехов в новых работах 😊

# %% [markdown]
# **Чек-лист готовности проекта**
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  Файл с данными открыт.
# - [x]  Файл с данными изучен: выведены первые строки, использован метод `info()`, построены гистограммы.
# - [x]  Найдены пропущенные значения.
# - [x]  Пропущенные значения заполнены там, где это возможно.
# - [x]  Объяснено, какие пропущенные значения обнаружены.
# - [x]  В каждом столбце установлен корректный тип данных.
# - [x]  Объяснено, в каких столбцах изменён тип данных и почему.
# - [x]  Устранены неявные дубликаты в названиях населённых пунктов.
# - [x]  Обработаны редкие и выбивающиеся значения (аномалии).
# - [x]  В таблицу добавлены новые параметры:
#        – цена одного квадратного метра;
#        – день публикации объявления (0 - понедельник, 1 - вторник и т. д.);
#        – месяц публикации объявления;
#        – год публикации объявления;
#        – тип этажа квартиры (значения — «первый», «последний», «другой»);
#        – расстояние до центра города в километрах.
# - [x]  Изучены и описаны параметры:
#         - общая площадь;
#         - жилая площадь;
#         - площадь кухни;
#         - цена объекта;
#         - количество комнат;
#         - высота потолков;
#         - тип этажа квартиры («первый», «последний», «другой»);
#         - общее количество этажей в доме;
#         - расстояние до центра города в метрах;
#         - расстояние до ближайшего парка.
# - [x]  Выполнено задание «Изучите, как быстро продавались квартиры (столбец `days_exposition`)»:
#     - построена гистограмма;
#     - рассчитаны среднее и медиана;
#     - описано, сколько обычно занимает продажа и указано, какие продажи можно считать быстрыми, а какие — необычно долгими.
# - [x]  Выполнено задание «Определите факторы, которые больше всего влияют на общую (полную) стоимость объекта». Построены графики, которые показывают зависимость цены от параметров:
#         - общая площадь;
#         - жилая площадь;
#         - площадь кухни;
#         - количество комнат;
#         - тип этажа, на котором расположена квартира (первый, последний, другой);
#         - дата размещения (день недели, месяц, год).
# - [x]  Выполнено задание «Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений»:
#     - выделены населённые пункты с самой высокой и низкой стоимостью квадратного метра.
# - [x]  Выполнено задание «Выделите квартиры в Санкт-Петербурге с помощью столбца `locality_name` и вычислите их среднюю стоимость на разном удалении от центра»:
#     -  учтён каждый километр расстояния, известны средние цены квартир в одном километре от центра, в двух и так далее;
#     -  описано, как стоимость объекта зависит от расстояния до центра города;
#     -  построен график изменения средней цены для каждого километра от центра Петербурга.
# - [x]  На каждом этапе сделаны промежуточные выводы.
# - [x]  В конце проекта сделан общий вывод.
